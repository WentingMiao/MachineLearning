# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('http://www.biointelligence.hu/ids/fuel_data_with_errors.txt', header=0, sep='\t')

# %%
data
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %% [markdown]
# <h1>Missing Values</h1>

# %%
data['starttemp'].isnull().sum()
# Out:
# 5

# %% [markdown]
# <b>Task 1</b><br>
# Write a for loop that calculates for each column of the data, how many missing values the column contains. Print the name of
# the column and the number of missing values. Hint: in order to get the column names, use <i>list(data)</i>.

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
for i in data.columns:
    print(i)
    print(data[i].isnull().sum())
# Out:
# date
# 0
# starttime
# 0
# endtime
# 0
# starttemp
# 5
# endtemp
# 4
# air conditioner
# 0
# trafic
# 0
# route
# 0
# dist
# 1
# avg.cons.
# 0
# speed
# 0
# duration
# 0
# fuel type
# 0
# road
# 0
# num. persons
# 0

# %% [markdown]
# <b>Task 2</b><br>
# Make a copy of the data, and set the missing values of starttemp to the <br>
# (a) mean <br>
# (b) median (if you do not know what is the median, please see: https://en.wikipedia.org/wiki/Median) <br>
# value of starttemp.<br>
# (c) What needs to be changed in your code to do the same for the other columns containing missing values?<br><br>

# %%
data2 = data.copy()

# %%
data2['starttemp'].fillna(value= data2['starttemp'].mean(),inplace=True)

# %%
data2
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
data2['starttemp'].fillna(value= data2['starttemp'].median())
# Out:
# 0      17.0
# 1      19.0
# 2      30.0
# 3      29.0
# 4      30.0
#        ...
# 98     21.0
# 99     16.0
# 100    17.0
# 101    15.0
# 102    21.0
# Name: starttemp, Length: 103, dtype: float64

# %%
data2['endtemp'].fillna(value= data2['endtemp'].mean(),inplace=True)

# %%
data2['dist'].fillna(value= data2['dist'].mean(),inplace=True)

# %%
data2
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
for i in data2.columns:
    print(i)
    print(data2[i].isnull().sum())
# Out:
# date
# 0
# starttime
# 0
# endtime
# 0
# starttemp
# 0
# endtemp
# 0
# air conditioner
# 0
# trafic
# 0
# route
# 0
# dist
# 0
# avg.cons.
# 0
# speed
# 0
# duration
# 0
# fuel type
# 0
# road
# 0
# num. persons
# 0

# %% [markdown]
# <b>Task 3</b><br>
# Create a scatter plot with <i>starttemp</i> and <i>endtemp</i> for the instances where both values are present (i.e., not missing). Hint: use <i>plt.scatter()</i>.

# %%
data3 = data.dropna()

# %%
plt.plot(data3.index,data3['starttemp'],color='r')

# %%
plt.plot(data3.index,data3['endtemp'],color='g')

# %%
plt.plot(data3.index,data3['starttemp'],color='r')
plt.plot(data3.index,data3['endtemp'],color='g')
plt.show()

# %% [markdown]
# <b>Task 4</b><br>
# The temperature at the arrival may be a better estimate than the mean or median. Replace the missing values of <i>starttemp</i> with the corresponding value of <i>endtemp</i>.

# %%
data[data['starttemp'].isnull()]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 14  2018.06.11     13:32   14:14        NaN     29.0              on     low
# 21  2018.06.20     17:30   18:26        NaN     28.0              on  normal
# 31  2017.06.28     08:25   09:30        NaN     20.0             off  normal
# 58  2018.07.18     18:30   19:33        NaN     19.0             off  normal
# 75  2018.08.09     09:15   10:15        NaN     29.0              on     low
#
#           route  dist  avg.cons.  speed duration fuel type      road  \
# 14   ercsi-dujv  36.7        4.5     53    00:41        FS  standard
# 21  szfvar-dujv  53.2        5.5     58    00:55       95+  standard
# 31      dujv-bp   NaN        5.0     67    01:02      95FS   highway
# 58      bp-dujv  71.8        5.0     66    01:04      95FS   highway
# 75      dujv-bp  69.7        5.2     70    00:59       95+   highway
#
#     num. persons
# 14             1
# 21             1
# 31             1
# ...

# %%
data4 = data.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4090bc843d0> in <module>
# ----> 1 data4 = data.copy()
#
# NameError: name 'data' is not defined

# %%
data4.loc[data4['starttemp'].isnull(),'starttemp']= data4[data4['starttemp'].isnull()]['endtemp']

# %%
data4
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %% [markdown]
# <b>Task 5</b><br>
# Calculate and plot the average differene (in case of non-missing values) between <i>starttemp</i> and <i>endtemp</i> as function of the hour of the day. Note that the time is stored as string.

# %%
data5 =  data.dropna()

# %%
data5
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
from datetime import datetime

# %%
data5.loc[12,'starttime']
# Out:
# '20:48'

# %%
start = datetime.strptime(data5.loc[12,'starttime'], '%H:%M')

# %%
end = datetime.strptime(data5.loc[12,'endtime'], '%H:%M')

# %%
type(start)
# Out:
# datetime.datetime

# %%
re = end - start

# %%
type(re)
# Out:
# datetime.timedelta

# %%
re.seconds
# Out:
# 4620

# %%
startlist = data5['starttime'].apply(lambda x : datetime.strptime(x,'%H:%M' ))

# %%
endlist = data5['endtime'].apply(lambda x : datetime.strptime(x,'%H:%M' ))

# %%
startlist.shape
# Out:
# (98,)

# %%
diffhour = (endlist -startlist).apply(lambda x : (x.seconds/3600))

# %%
diffhour
# Out:
# 0      1.216667
# 1      1.150000
# 2      2.000000
# 3      1.000000
# 4      0.866667
#          ...
# 98     0.916667
# 99     1.216667
# 100    1.166667
# 101    1.166667
# 102    1.033333
# Length: 98, dtype: float64

# %%
type(diffhour)
# Out:
# pandas.core.series.Series

# %%
data5['diffhours'] = diffhour
# Out:
# D:\pyt\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data5
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
data5['difftemp']=abs(data5['endtemp']-data5['starttemp'])
# Out:
# D:\pyt\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data5
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
r = data5.groupby('diffhours').mean()['difftemp']

# %%
r
# Out:
# diffhours
# 0.483333     0.000000
# 0.500000     2.000000
# 0.600000     2.000000
# 0.616667     3.000000
# 0.666667     2.000000
# 0.700000     0.000000
# 0.750000     2.000000
# 0.800000     6.000000
# 0.833333     2.250000
# 0.866667     2.500000
# 0.883333     1.000000
# 0.916667     1.000000
# 0.933333     2.333333
# 0.950000     5.000000
# 0.983333     3.000000
# 1.000000     1.615385
# 1.016667     5.000000
# 1.033333     2.000000
# 1.050000     1.400000
# 1.066667     2.000000
# 1.083333     1.571429
# 1.100000     2.000000
# 1.116667     4.000000
# 1.133333     3.500000
# 1.150000     5.000000
# 1.166667     2.800000
# 1.183333     3.000000
# 1.200000    92.000000
# 1.216667     1.666667
# 1.233333     6.000000
# 1.250000     3.666667
# 1.266667     0.600000
# 1.283333     1.000000
# 1.333333     2.500000
# 1.350000     4.000000
# 1.400000     5.000000
# 1.416667     3.000000
# 1.450000     6.000000
# 1.583333     4.500000
# 1.616667     4.000000
# 1.666667     2.000000
# ...

# %%
type(r)
# Out:
# pandas.core.series.Series

# %%
data5[data5['starttemp']==data5['endtemp']]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  \
# 5   2018.06.05     21:04   22:20       25.0     25.0             off
# 6   2018.06.05     21:04   22:20       25.0     25.0             off
# 7   2018.06.05     21:04   22:20       25.0     25.0             off
# 14  2018.06.11     13:32   14:14       29.0     29.0              on
# 16  2018.06.12     12:45   13:37       30.0     30.0              on
# 21  2018.06.20     17:30   18:26       28.0     28.0              on
# 30  2017.06.27     17:03   17:32       14.0     14.0             off
# 35  2017.06.30     14:40   15:30       27.0     27.0              on
# 45  2018.07.06     18:58   20:01       22.0     22.0             off
# 51  2018.07.09     18:00   19:00       29.0     29.0              on
# 58  2018.07.18     18:30   19:33       19.0     19.0             off
# 60  2018.07.20     17:45   18:40       27.0     27.0              on
# 68  2018.07.31     09:00   10:00       23.0     23.0              on
# ...

# %%
##wrong
##result = abs(data5['endtemp']-data5['starttemp'])/diffhour

# %%
##wrong 
##result

# %%
p=plt.plot(r.index,r,color='black')

# %% [markdown]
# <b>Task 6</b><br>
# Based on the previous task, can you propose a better strategy to fill the missing values of <i>starttemp</i>?

# %%
##1.we can calculate the starttemp based on the endtemp and difftemp corresponding 
##2.depend on the time if its on morning ,starttemp = endtemp-difftemp 
##        if its on evening ,starttemp = endtemp+difftemp

# %%
data6 = pd.read_csv('http://www.biointelligence.hu/ids/fuel_data_with_errors.txt', header=0, sep='\t')

# %%
startlist2 = data6['starttime'].apply(lambda x : datetime.strptime(x,'%H:%M' ))

# %%
endlist2 = data6['endtime'].apply(lambda x : datetime.strptime(x,'%H:%M' ))

# %%
diffhour2 = (endlist2 -startlist2).apply(lambda x : (x.seconds/3600))

# %%
diffhour2.isnull().sum()
# Out:
# 0

# %%
data6
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
data6['diffhours'] = diffhour2

# %%
data6
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %%
##use the result from previous task
diffhourDifftemp = r

# %%
diffhourDifftemp
# Out:
# diffhours
# 0.483333     0.000000
# 0.500000     2.000000
# 0.600000     2.000000
# 0.616667     3.000000
# 0.666667     2.000000
# 0.700000     0.000000
# 0.750000     2.000000
# 0.800000     6.000000
# 0.833333     2.250000
# 0.866667     2.500000
# 0.883333     1.000000
# 0.916667     1.000000
# 0.933333     2.333333
# 0.950000     5.000000
# 0.983333     3.000000
# 1.000000     1.615385
# 1.016667     5.000000
# 1.033333     2.000000
# 1.050000     1.400000
# 1.066667     2.000000
# 1.083333     1.571429
# 1.100000     2.000000
# 1.116667     4.000000
# 1.133333     3.500000
# 1.150000     5.000000
# 1.166667     2.800000
# 1.183333     3.000000
# 1.200000    92.000000
# 1.216667     1.666667
# 1.233333     6.000000
# 1.250000     3.666667
# 1.266667     0.600000
# 1.283333     1.000000
# 1.333333     2.500000
# 1.350000     4.000000
# 1.400000     5.000000
# 1.416667     3.000000
# 1.450000     6.000000
# 1.583333     4.500000
# 1.616667     4.000000
# 1.666667     2.000000
# ...

# %%
diffhourDifftemp[0.5]
# Out:
# 2.0

# %%
nullRow = data6['starttemp'].isnull()

# %%
nullRow
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 98     False
# 99     False
# 100    False
# 101    False
# 102    False
# Name: starttemp, Length: 103, dtype: bool

# %%
data6.loc[nullRow,'starttemp']
# Out:
# 14   NaN
# 21   NaN
# 31   NaN
# 58   NaN
# 75   NaN
# Name: starttemp, dtype: float64

# %%
endtimeHour = data6['endtime'].apply(lambda x : datetime.strptime(x,'%H:%M' ).hour)

# %%
endtimeHour
# Out:
# 0       1
# 1       9
# 2      15
# 3      16
# 4      19
#        ..
# 98     22
# 99      7
# 100    21
# 101     9
# 102    21
# Name: endtime, Length: 103, dtype: int64

# %%
data6['endtimeHour'] = endtimeHour

# %%
(-1)**data6.loc[nullRow,'endtimeHour'].apply(lambda x: x>=12)
# Out:
# 14   -1
# 21   -1
# 31    1
# 58   -1
# 75    1
# Name: endtimeHour, dtype: int32

# %%
data6[nullRow]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 14  2018.06.11     13:32   14:14        NaN     29.0              on     low
# 21  2018.06.20     17:30   18:26        NaN     28.0              on  normal
# 31  2017.06.28     08:25   09:30        NaN     20.0             off  normal
# 58  2018.07.18     18:30   19:33        NaN     19.0             off  normal
# 75  2018.08.09     09:15   10:15        NaN     29.0              on     low
#
#           route  dist  avg.cons.  speed duration fuel type      road  \
# 14   ercsi-dujv  36.7        4.5     53    00:41        FS  standard
# 21  szfvar-dujv  53.2        5.5     58    00:55       95+  standard
# 31      dujv-bp   NaN        5.0     67    01:02      95FS   highway
# 58      bp-dujv  71.8        5.0     66    01:04      95FS   highway
# 75      dujv-bp  69.7        5.2     70    00:59       95+   highway
#
#     num. persons  diffhours  endtimeHour
# 14             1   0.700000           14
# ...

# %%
data6.loc[nullRow,'diffhours']
# Out:
# 14    0.700000
# 21    0.933333
# 31    1.083333
# 58    1.050000
# 75    1.000000
# Name: diffhours, dtype: float64

# %%
##there is no value for index 0.7 in diffhourDifftemp
##but 0.666667 and 0.75 value both are 2
##we suppose 0.7 have also value 2.
diffhourDifftemp[0.7] = 2

# %%
data6.loc[nullRow,'diffhours'].iloc[0]
# Out:
# 0.7

# %%
diffhourDifftemp[data6.loc[nullRow,'diffhours'].iloc[1]]
# Out:
# 2.3333333333333335

# %%
data6.loc[nullRow,'diffhours'].apply(lambda x:diffhourDifftemp[x] )
# Out:
# 14    2.000000
# 21    2.333333
# 31    1.571429
# 58    1.400000
# 75    1.615385
# Name: diffhours, dtype: float64

# %%
tempchange = data6.loc[nullRow,'diffhours'].apply(lambda x:diffhourDifftemp[x] ) *(-1)**data6.loc[nullRow,'endtimeHour'].apply(lambda x: x>=12)

# %%
tempchange
# Out:
# 14   -2.000000
# 21   -2.333333
# 31    1.571429
# 58   -1.400000
# 75    1.615385
# dtype: float64

# %%
data6.loc[nullRow,'starttemp'] =data6.loc[nullRow,'endtemp']-tempchange

# %%
data6.iloc[14]
# Out:
# date               2018.06.11
# starttime               13:32
# endtime                 14:14
# starttemp                  31
# endtemp                    29
# air conditioner            on
# trafic                    low
# route              ercsi-dujv
# dist                     36.7
# avg.cons.                 4.5
# speed                      53
# duration                00:41
# fuel type                  FS
# road                 standard
# num. persons                1
# diffhours                 0.7
# endtimeHour                14
# Name: 14, dtype: object

# %% [markdown]
# <b>Task 7</b><br>
# How would you fill the missing values of the <i>distance</i>?

# %%
##the value of distance equal the difference between starttime multiply endtime ,speed.
#fomular  : distance = (endtime-starttime ) * speed

# %%
data7 = pd.read_csv('http://www.biointelligence.hu/ids/fuel_data_with_errors.txt', header=0, sep='\t')

# %%
nullRow2 = data7['dist'].isnull()

# %%
data7[nullRow2]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 31  2017.06.28     08:25   09:30        NaN     20.0             off  normal
#
#       route  dist  avg.cons.  speed duration fuel type     road  num. persons
# 31  dujv-bp   NaN        5.0     67    01:02      95FS  highway             1

# %%
duration7 = data7.loc[nullRow2,'duration'].apply(lambda x :datetime.strptime(x,'%H:%M' ))

# %%
type(duration7)
# Out:
# pandas.core.series.Series

# %%
period=duration7.dt.hour+duration7.dt.minute/60

# %%
type(period)
# Out:
# pandas.core.series.Series

# %%
period
# Out:
# 31    1.033333
# Name: duration, dtype: float64

# %%
data7.loc[nullRow2,'dist'] = data7.loc[nullRow2,'speed']*period

# %%
data7.loc[nullRow2,'dist']
# Out:
# 31    69.233333
# Name: dist, dtype: float64

# %%
data7[nullRow2]
# Out:
#           date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 31  2017.06.28     08:25   09:30        NaN     20.0             off  normal
#
#       route       dist  avg.cons.  speed duration fuel type     road  \
# 31  dujv-bp  69.233333        5.0     67    01:02      95FS  highway
#
#     num. persons
# 31             1

# %% [markdown]
# <h1>Duplicate Elimination</h1>

# %% [markdown]
# <b>Task 8</b><br>
# Elimination of exact duplicates is usually performed in two steps: first, the data is sorted. The, subsequent records are checked if they are duplicates or not. Now, the data is already sorted, therefore, you only need to check if subsequent records have the same values.

# %%
data8=data

# %%
data8 = data8.drop_duplicates()
data8
# Out:
#            date starttime endtime  starttemp  endtemp air conditioner  trafic  \
# 0    2018.06.03     00:03   01:16       17.0     15.0             off     low
# 1    2018.06.03     08:20   09:29       19.0     24.0             off     low
# 2    2018.06.03     13:00   15:00       30.0     28.0              on  normal
# 3    2018.06.04     15:30   16:30       29.0     28.0              on  normal
# 4    2018.06.04     18:18   19:10       30.0     25.0              on  normal
# ..          ...       ...     ...        ...      ...             ...     ...
# 98   2018.09.03     22:00   22:55       21.0     19.0             off  normal
# 99   2018.09.04     06:42   07:55       16.0     17.0             off  normal
# 100  2018.09.04     20:00   21:10       17.0     16.0             off     low
# 101  2018.09.05     08:15   09:25       15.0     20.0             off  normal
# 102  2018.09.05     20:50   21:52       21.0     19.0             off     low
#
# ...

# %% [markdown]
# <h1>Outlier Detection</h1>

# %% [markdown]
# <b>Task 9</b><br>
# Using boxplots, determine the outliers (values that are very different from the majority of the values) for each column.

# %%
df = pd.DataFrame(data)
df.plot.box()
plt.grid(linestyle="--", alpha=0.3)
plt.show()

# %% [markdown]
# <h1>Inconsistent Values</h1>

# %% [markdown]
# <b>Task 10</b><br>
# In order to determine the inconsistent values, first, examine occurrence count of each value for each column. Hint: use <i>groupby</i> and <i>count</i>.

# %%
data10=data
data10.groupby('date').count()
# Out:
#             starttime  endtime  starttemp  endtemp  air conditioner  trafic  \
# date
# 2017.06.27          1        1          1        1                1       1
# 2017.06.28          2        2          2        2                2       2
# 2017.06.29          1        1          1        1                1       1
# 2017.06.30          4        4          4        4                4       4
# 2017.07.02          2        2          2        2                2       2
# 2018.06.03          3        3          3        3                3       3
# 2018.06.04          2        2          2        2                2       2
# 2018.06.05          3        3          3        3                3       3
# 2018.06.07          2        2          2        2                2       2
# 2018.06.08          1        1          1        1                1       1
# 2018.06.10          2        2          2        2                2       2
# ...

# %%
data10.describe()
# Out:
#         starttemp     endtemp        dist   avg.cons.       speed  \
# count  103.000000   99.000000  102.000000  103.000000  103.000000
# mean    22.854369   24.454545   68.771569    5.229126   61.805825
# std      5.552614   18.322103   21.024886    1.495263   10.765830
# min     11.000000   12.000000    0.600000    0.100000    1.000000
# 25%     18.000000   20.000000   64.850000    4.650000   57.000000
# 50%     22.000000   23.000000   71.100000    5.100000   62.000000
# 75%     28.000000   26.000000   72.100000    5.500000   68.000000
# max     33.000000  200.000000  173.900000   18.100000   95.000000
#
#        num. persons
# count    103.000000
# mean       1.300971
# std        0.639162
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000

# %% [markdown]
# <b>Task 11</b><br>
# Using the above <i>iterative_levenshtein</i> function, for each inconsistent value of string-valued columns, calculate the most appropriate replacement.

# %%
def iterative_levenshtein(s, t):
    """ 
        source: https://www.python-course.eu/levenshtein_distance.php
        
        iterative_levenshtein(s, t) -> ldist
        ldist is the Levenshtein distance between the strings 
        s and t.
        For all i and j, dist[i,j] will contain the Levenshtein 
        distance between the first i characters of s and the 
        first j characters of t
    """
    rows = len(s)+1
    cols = len(t)+1
    dist = [[0 for x in range(cols)] for x in range(rows)]
    # source prefixes can be transformed into empty strings 
    # by deletions:
    for i in range(1, rows):
        dist[i][0] = i
    # target prefixes can be created from an empty source string
    # by inserting the characters
    for i in range(1, cols):
        dist[0][i] = i
        
    for col in range(1, cols):
        for row in range(1, rows):
            if s[row-1] == t[col-1]:
                cost = 0
            else:
                cost = 1
            dist[row][col] = min(dist[row-1][col] + 1,      # deletion
                                 dist[row][col-1] + 1,      # insertion
                                 dist[row-1][col-1] + cost) # substitution

    return dist[row][col]

# %%
median = data['starttemp'].median()
median
data['starttemp'].fillna(median, inplace =True)
data['starttemp']
# Out:
# 0      17.0
# 1      19.0
# 2      30.0
# 3      29.0
# 4      30.0
#        ...
# 98     21.0
# 99     16.0
# 100    17.0
# 101    15.0
# 102    21.0
# Name: starttemp, Length: 103, dtype: float64

# %%
# Out:
# 22.0
